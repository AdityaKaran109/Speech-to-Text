# %%
#!pip install SpeechRecognition
#!pip install fpdf
#!pip install pyaudio
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.13.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 95.6 kB/s eta 0:00:00 kB/s eta 0:00:01:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (pyproject.toml) ... done
#   Created wheel for pyaudio: filename=PyAudio-0.2.13-cp310-cp310-linux_x86_64.whl size=27814 sha256=98216b2bc622e80a891daddc4f3c38097cd21cebb2943c7aeea8bc10f9206659
#   Stored in directory: /home/aditya/.cache/pip/wheels/9e/3d/ab/c92aec70a8d45cb9b8feb9476ca46616cdb5c78b00dcfb0afd
# Successfully built pyaudio
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.13

# %%
import speech_recognition as sr
from datetime import datetime
from fpdf import FPDF
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Initializing the recognizer
r = sr.Recognizer()

# %%
# Setting the microphone as source
with sr.Microphone() as source:

    # Setting the energy threshold for ambient noise
    r.adjust_for_ambient_noise(source)

    # Starting the note-taking loop
    while True:
        
        # Listening to the speech input
        print("Say something!")
        audio = r.listen(source, phrase_time_limit=5)

        try:
            # Converting speech to text
            text = r.recognize_google(audio)
            
            # Checking if the note should start
            if text.lower() == "make a note":
                print("Note started...")
                
                # Starting to record the note
                note = ""
                bullet_point = 0
                
                # Looping to listen to speech input and add to the note
                while True:
                    
                    # Listening to the speech input
                    print("Listening...")
                    audio = r.listen(source, phrase_time_limit=5)
                    
                    try:
                        # Converting speech to text
                        text = r.recognize_google(audio)
                        print(text)
                        
                        # Checking if the note should end
                        if "stop listening" in text.lower():
                            print("Note ended.")
                            break
                        
                        # Adding the speech input to the note as a bullet point
                        note += str(bullet_point) + ". " + text + "\n"
                        bullet_point += 1
                        
                    except sr.UnknownValueError:
                        print("Could not understand audio")
                    
                    except sr.RequestError as e:
                        print("Could not request results; {0}".format(e))
                
                # Creating the PDF file and saving the note
                pdf = FPDF()
                pdf.add_page()
                pdf.set_font("Arial", size=12)
                pdf.cell(200, 10, txt="NOTE - " + str(datetime.now()), ln=1, align="C")
                pdf.multi_cell(0, 10, txt=note)
                pdf.output("note_" + str(datetime.now().strftime("%Y-%m-%d_%H-%M-%S")) + ".pdf")
            
        except sr.UnknownValueError:
            print("Could not understand audio")
        
        except sr.RequestError as e:
            print("Could not request results; {0}".format(e))
# Out:
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.front.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM front
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround21
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround21
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround40.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround40
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround41
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround50
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround51
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround71.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround71
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM iec958
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM spdif
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM spdif
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline
# ALSA lib pcm_oss.c:377:(_snd_pcm_oss_open) Unknown field port
# ALSA lib pcm_oss.c:377:(_snd_pcm_oss_open) Unknown field port
# ALSA lib pcm_usb_stream.c:486:(_snd_pcm_usb_stream_open) Invalid type for card
# ALSA lib pcm_usb_stream.c:486:(_snd_pcm_usb_stream_open) Invalid type for card
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.front.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM front
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround21
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround21
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround40.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround40
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround41
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround50
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround51.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround51
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.surround71.0:CARD=0'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM surround71
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM iec958
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM spdif
# ALSA lib confmisc.c:1281:(snd_func_refer) Unable to find definition 'cards.sof-hda-dsp.pcm.iec958.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:4732:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5220:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM spdif
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.hdmi
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.modem
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline
# ALSA lib pcm.c:2642:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline
# ALSA lib pcm_oss.c:377:(_snd_pcm_oss_open) Unknown field port
# ALSA lib pcm_oss.c:377:(_snd_pcm_oss_open) Unknown field port
# ALSA lib pcm_usb_stream.c:486:(_snd_pcm_usb_stream_open) Invalid type for card
# ALSA lib pcm_usb_stream.c:486:(_snd_pcm_usb_stream_open) Invalid type for card
# Say something!
# Say something!
# Could not understand audio
# Say something!
# Note started...
# Listening...
# make a note
# Listening...
# Could not understand audio
# Listening...
# my name is Aditya my name
# Listening...
# Could not understand audio
# Listening...
# Could not understand audio
# Listening...
# top listener top listening
# Listening...
# stop listening
# Note ended.
# Say something!
# Could not understand audio
# Say something!
# Could not understand audio
# Say something!
# Could not understand audio
# Say something!
# Could not understand audio
# Say something!
# Say something!
# Could not understand audio
# Say something!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 12
#       8 while True:
#       9
#      10     # Listening to the speech input
#      11     print("Say something!")
# ---> 12     audio = r.listen(source, phrase_time_limit=5)
#      14     try:
#      15         # Converting speech to text
#      16         text = r.recognize_google(audio)
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:523, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     520 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     521     break
# --> 523 buffer = source.stream.read(source.CHUNK)
#     524 if len(buffer) == 0: break  # reached end of the stream
#     525 frames.append(buffer)
#
# File ~/anaconda3/lib/python3.10/site-packages/speech_recognition/__init__.py:199, in Microphone.MicrophoneStream.read(self, size)
#     198 def read(self, size):
# --> 199     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~/anaconda3/lib/python3.10/site-packages/pyaudio/__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
